# %%
import os

import pandas as pd

# %%
FILENAME = 'vocabulary_rp.csv'

# %%
FILEPATH = os.path.join(os.getcwd(), FILENAME)

# %%
dataframe = pd.read_csv(FILEPATH, sep=';').sort_values(by='word').drop_duplicates().reset_index(drop=True)
dataframe.to_csv(FILEPATH, sep=';', index=False)
dataframe
# Out:
#                   word        transcription  \
# 0    (T1/T2) weighting              ˈweɪtɪŋ
# 1    Fourier transform  ˈfʊriːeɪ ˈtrænsfɔːm
# 2    Glan Taylor Prism  Glan ˈteɪlə ˈprɪzəm
# 3      a baseline scan    ə ˈbeɪsˌlaɪn skæn
# 4           absorption         əbˈzɔːpʃ(ə)n
# ..                 ...                  ...
# 164             vessel             'ves(ə)l
# 165              virus              ˈvaɪrəs
# 166               wave                 weɪv
# 167         weathering             ˈweðərɪŋ
# 168         widespread           ˈwaɪdsprɛd
#
#                                translation  success_number  learning_date
# 0                               взвешенный               0            NaN
# 1                     преобразование Фурье               0            NaN
# 2                      призма Яна-Тейлораэ               0            NaN
# 3                     базовое сканирование               0            NaN
# ...
