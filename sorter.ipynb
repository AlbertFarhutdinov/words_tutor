# %%
import os

import pandas as pd

# %%
FILENAME = 'vocabulary_master.csv'

# %%
FILEPATH = os.path.join(os.getcwd(), FILENAME)

# %%
dataframe = pd.read_csv(FILEPATH, sep=';').sort_values(by='word').reset_index(drop=True)
dataframe.to_csv(FILEPATH, sep=';', index=False)
dataframe
# Out:
#              word    transcription            translation  success_number  \
# 0          access           ˈækses                 доступ               0
# 1    accumulating  əˈkjuːmjʊleɪtɪŋ          накапливающий               0
# 2         achieve           əˈʧiːv  достигать, добиваться               0
# 3    achievements     əˈtʃiːvmənts             достижения               0
# 4         acquire          əˈkwaɪə            приобретать               0
# ..            ...              ...                    ...             ...
# 195      verbatim       və:ˈbeɪtɪm              дословный               0
# 196       victory       ˈvɪkt(ə)ri                 победа               0
# 197       warfare        ˈwɔː.feər                  война               0
# 198      weigh up          weɪ  ʌp       взвесить, решить               0
# 199        émigré         ˈemɪɡreɪ               эмигрант               0
#
#      learning_date
# 0              NaN
# 1              NaN
# ...
